# %%
# import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot([31,23,45,35,234,56,3])
plt.show()

# %%
iris=sns.load_dataset("iris")
# get_dataset("iris")
a=sns.swarmplot(x="sepal_length",y="species",data=iris)

# %%
b=sns.stripplot(x='species', y='sepal_length', data=iris)
plt.show()
